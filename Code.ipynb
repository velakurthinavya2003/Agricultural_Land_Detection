# %%
# !git clone https://github.com/velakurthinavya2003/changedtest
# Out:
# fatal: destination path 'changedtest' already exists and is not an empty directory.

# %%
# %cd /content/gitcommand/Semantic\ segmentation\ dataset
# Out:
# [Errno 2] No such file or directory: '/content/gitcommand/Semantic segmentation dataset'
# /content

# %%
# !ls
# Out:
# changedtest  sample_data

# %%
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization, Dropout, Lambda
from keras import backend as K

def jacard_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) - intersection + 1.0)



################################################################
def multi_unet_model(n_classes=4, IMG_HEIGHT=256, IMG_WIDTH=256, IMG_CHANNELS=1):
#Build the model
    inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
    #s = Lambda(lambda x: x / 255)(inputs)   #No need for this if we normalize our inputs beforehand
    s = inputs

    #Contraction path
    c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(s)
    c1 = Dropout(0.2)(c1)  # Original 0.1
    c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
    p1 = MaxPooling2D((2, 2))(c1)

    c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
    c2 = Dropout(0.2)(c2)  # Original 0.1
    c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
    p2 = MaxPooling2D((2, 2))(c2)

    c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
    c3 = Dropout(0.2)(c3)
    c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
    p3 = MaxPooling2D((2, 2))(c3)

    c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
    c4 = Dropout(0.2)(c4)
    c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
    p4 = MaxPooling2D(pool_size=(2, 2))(c4)

    c5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
    c5 = Dropout(0.3)(c5)
    c5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)

    #Expansive path
    u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c5)
    u6 = concatenate([u6, c4])
    c6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u6)
    c6 = Dropout(0.2)(c6)
    c6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)

    u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = concatenate([u7, c3])
    c7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u7)
    c7 = Dropout(0.2)(c7)
    c7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)

    u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c7)
    u8 = concatenate([u8, c2])
    c8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u8)
    c8 = Dropout(0.2)(c8)  # Original 0.1
    c8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)

    u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c8)
    u9 = concatenate([u9, c1], axis=3)
    c9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u9)
    c9 = Dropout(0.2)(c9)  # Original 0.1
    c9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)

    outputs = Conv2D(n_classes, (1, 1), activation='softmax')(c9)

    model = Model(inputs=[inputs], outputs=[outputs])

    #NOTE: Compile the model in the main program to make it easy to test with various loss functions
    #model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    # model.summary()

    return model

# %%
# !pip install patchify
# Out:
# Requirement already satisfied: patchify in /usr/local/lib/python3.10/dist-packages (0.2.3)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from patchify) (1.25.2)

# %%
# !pip install segmentation_models
# Out:
# Requirement already satisfied: segmentation_models in /usr/local/lib/python3.10/dist-packages (1.0.1)
# Requirement already satisfied: keras-applications<=1.0.8,>=1.0.7 in /usr/local/lib/python3.10/dist-packages (from segmentation_models) (1.0.8)
# Requirement already satisfied: image-classifiers==1.0.0 in /usr/local/lib/python3.10/dist-packages (from segmentation_models) (1.0.0)
# Requirement already satisfied: efficientnet==1.0.0 in /usr/local/lib/python3.10/dist-packages (from segmentation_models) (1.0.0)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from efficientnet==1.0.0->segmentation_models) (0.19.3)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation_models) (1.25.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation_models) (3.9.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (1.11.4)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (3.3)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (9.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (2024.7.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (1.6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (24.1)

# %%
# %cd /content/newtest/Semantic\ segmentation\ dataset
# Out:
# [Errno 2] No such file or directory: '/content/newtest/Semantic segmentation dataset'
# /content

# %%
import os
import cv2
import numpy as np

from matplotlib import pyplot as plt
from patchify import patchify
from PIL import Image
import segmentation_models as sm
from tensorflow.keras.metrics import MeanIoU

from sklearn.preprocessing import MinMaxScaler, StandardScaler
scaler = MinMaxScaler()
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization, Dropout, Lambda
from keras import backend as K

def jacard_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) - intersection + 1.0)



################################################################
def multi_unet_model(n_classes=4, IMG_HEIGHT=256, IMG_WIDTH=256, IMG_CHANNELS=1):
#Build the model
    inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
    #s = Lambda(lambda x: x / 255)(inputs)   #No need for this if we normalize our inputs beforehand
    s = inputs

    #Contraction path
    c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(s)
    c1 = Dropout(0.2)(c1)  # Original 0.1
    c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
    p1 = MaxPooling2D((2, 2))(c1)

    c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
    c2 = Dropout(0.2)(c2)  # Original 0.1
    c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
    p2 = MaxPooling2D((2, 2))(c2)

    c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
    c3 = Dropout(0.2)(c3)
    c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
    p3 = MaxPooling2D((2, 2))(c3)

    c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
    c4 = Dropout(0.2)(c4)
    c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
    p4 = MaxPooling2D(pool_size=(2, 2))(c4)

    c5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
    c5 = Dropout(0.3)(c5)
    c5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)

    #Expansive path
    u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c5)
    u6 = concatenate([u6, c4])
    c6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u6)
    c6 = Dropout(0.2)(c6)
    c6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)

    u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = concatenate([u7, c3])
    c7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u7)
    c7 = Dropout(0.2)(c7)
    c7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)

    u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c7)
    u8 = concatenate([u8, c2])
    c8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u8)
    c8 = Dropout(0.2)(c8)  # Original 0.1
    c8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)

    u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c8)
    u9 = concatenate([u9, c1], axis=3)
    c9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u9)
    c9 = Dropout(0.2)(c9)  # Original 0.1
    c9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)

    outputs = Conv2D(n_classes, (1, 1), activation='softmax')(c9)

    model = Model(inputs=[inputs], outputs=[outputs])

    #NOTE: Compile the model in the main program to make it easy to test with various loss functions
    #model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    # model.summary()

    return model

root_directory = '/content/changedtest/Semantic segmentation dataset'

patch_size = 256
image_dataset = []
for path, subdirs, files in os.walk(root_directory):
    #print(path)
    dirname = path.split(os.path.sep)[-1]
    if dirname == 'images':   #Find all 'images' directories
        images = os.listdir(path)  #List of all image names in this subdirectory
        for i, image_name in enumerate(images):
            if image_name.endswith(".jpg"):   #Only read jpg images...

                image = cv2.imread(path+"/"+image_name, 1)  #Read each image as BGR
                SIZE_X = (image.shape[1]//patch_size)*patch_size #Nearest size divisible by our patch size
                SIZE_Y = (image.shape[0]//patch_size)*patch_size #Nearest size divisible by our patch size
                image = Image.fromarray(image)
                image = image.crop((0 ,0, SIZE_X, SIZE_Y))  #Crop from top left corner
                #image = image.resize((SIZE_X, SIZE_Y))  #Try not to resize for semantic segmentation
                image = np.array(image)

                #Extract patches from each image
                print("Now patchifying image:", path+"/"+image_name)
                patches_img = patchify(image, (patch_size, patch_size, 3), step=patch_size)  #Step=256 for 256 patches means no overlap

                for i in range(patches_img.shape[0]):
                    for j in range(patches_img.shape[1]):

                        single_patch_img = patches_img[i,j,:,:]

                        #Use minmaxscaler instead of just dividing by 255.
                        single_patch_img = scaler.fit_transform(single_patch_img.reshape(-1, single_patch_img.shape[-1])).reshape(single_patch_img.shape)

                        #single_patch_img = (single_patch_img.astype('float32')) / 255.
                        single_patch_img = single_patch_img[0] #Drop the extra unecessary dimension that patchify adds.
                        image_dataset.append(single_patch_img)




 #Now do the same as above for masks
 #For this specific dataset we could have added masks to the above code as masks have extension png
mask_dataset = []
for path, subdirs, files in os.walk(root_directory):
    #print(path)
    dirname = path.split(os.path.sep)[-1]
    if dirname == 'masks':   #Find all 'images' directories
        masks = os.listdir(path)  #List of all image names in this subdirectory
        for i, mask_name in enumerate(masks):
            if mask_name.endswith(".png"):   #Only read png images... (masks in this dataset)

                mask = cv2.imread(path+"/"+mask_name, 1)  #Read each image as Grey (or color but remember to map each color to an integer)
                mask = cv2.cvtColor(mask,cv2.COLOR_BGR2RGB)
                SIZE_X = (mask.shape[1]//patch_size)*patch_size #Nearest size divisible by our patch size
                SIZE_Y = (mask.shape[0]//patch_size)*patch_size #Nearest size divisible by our patch size
                mask = Image.fromarray(mask)
                mask = mask.crop((0 ,0, SIZE_X, SIZE_Y))  #Crop from top left corner
                #mask = mask.resize((SIZE_X, SIZE_Y))  #Try not to resize for semantic segmentation
                mask = np.array(mask)

                #Extract patches from each image
                print("Now patchifying mask:", path+"/"+mask_name)
                patches_mask = patchify(mask, (patch_size, patch_size, 3), step=patch_size)  #Step=256 for 256 patches means no overlap

                for i in range(patches_mask.shape[0]):
                    for j in range(patches_mask.shape[1]):

                        single_patch_mask = patches_mask[i,j,:,:]
                        #single_patch_img = (single_patch_img.astype('float32')) / 255. #No need to scale masks, but you can do it if you want
                        single_patch_mask = single_patch_mask[0] #Drop the extra unecessary dimension that patchify adds.
                        mask_dataset.append(single_patch_mask)

image_dataset = np.array(image_dataset)
mask_dataset =  np.array(mask_dataset)

#Sanity check, view few mages
import random
import numpy as np
image_number = random.randint(0, len(image_dataset))
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(np.reshape(image_dataset[image_number], (patch_size, patch_size, 3)))
plt.subplot(122)
plt.imshow(np.reshape(mask_dataset[image_number], (patch_size, patch_size, 3)))
plt.show()
a=int('3C', 16)  #3C with base 16. Should return 60.
print(a)
#Do the same for all RGB channels in each hex code to convert to RGB
Building = '#3C1098'.lstrip('#')
Building = np.array(tuple(int(Building[i:i+2], 16) for i in (0, 2, 4))) # 60, 16, 152

Land = '#8429F6'.lstrip('#')
Land = np.array(tuple(int(Land[i:i+2], 16) for i in (0, 2, 4))) #132, 41, 246

Road = '#6EC1E4'.lstrip('#')
Road = np.array(tuple(int(Road[i:i+2], 16) for i in (0, 2, 4))) #110, 193, 228

Vegetation =  'FEDD3A'.lstrip('#')
Vegetation = np.array(tuple(int(Vegetation[i:i+2], 16) for i in (0, 2, 4))) #254, 221, 58

Water = 'E2A929'.lstrip('#')
Water = np.array(tuple(int(Water[i:i+2], 16) for i in (0, 2, 4))) #226, 169, 41

Unlabeled = '#9B9B9B'.lstrip('#')
Unlabeled = np.array(tuple(int(Unlabeled[i:i+2], 16) for i in (0, 2, 4))) #155, 155, 155

label = single_patch_mask
def rgb_to_2D_label(label):
    """
    Suply our labale masks as input in RGB format.
    Replace pixels with specific RGB values ...
    """
    label_seg = np.zeros(label.shape,dtype=np.uint8)
    label_seg [np.all(label == Building,axis=-1)] = 0
    label_seg [np.all(label==Land,axis=-1)] = 1
    label_seg [np.all(label==Road,axis=-1)] = 2
    label_seg [np.all(label==Vegetation,axis=-1)] = 3
    label_seg [np.all(label==Water,axis=-1)] = 4
    label_seg [np.all(label==Unlabeled,axis=-1)] = 5

    label_seg = label_seg[:,:,0]  #Just take the first channel, no need for all 3 channels

    return label_seg

labels = []
for i in range(mask_dataset.shape[0]):
    label = rgb_to_2D_label(mask_dataset[i])
    labels.append(label)

labels = np.array(labels)
labels = np.expand_dims(labels, axis=3)


print("Unique labels in label dataset are: ", np.unique(labels))

#Another Sanity check, view few mages
import random
import numpy as np
image_number = random.randint(0, len(image_dataset))
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(image_dataset[image_number])
plt.subplot(122)
plt.imshow(labels[image_number][:,:,0])
plt.show()

n_classes = len(np.unique(labels))
from keras.utils import to_categorical
labels_cat = to_categorical(labels, num_classes=n_classes)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(image_dataset, labels_cat, test_size = 0.20, random_state = 42)


#######################################
#Parameters for model
# Segmentation models losses can be combined together by '+' and scaled by integer or float factor
# set class weights for dice_loss
# from sklearn.utils.class_weight import compute_class_weight

# weights = compute_class_weight('balanced', np.unique(np.ravel(labels,order='C')),
#                               np.ravel(labels,order='C'))
# print(weights)

weights = [0.1666, 0.1666, 0.1666, 0.1666, 0.1666, 0.1666]
dice_loss = sm.losses.DiceLoss(class_weights=weights)
focal_loss = sm.losses.CategoricalFocalLoss()
total_loss = dice_loss + (1 * focal_loss)  #


IMG_HEIGHT = X_train.shape[1]
IMG_WIDTH  = X_train.shape[2]
IMG_CHANNELS = X_train.shape[3]



metrics=['accuracy', jacard_coef]

def get_model():
    return multi_unet_model(n_classes=n_classes, IMG_HEIGHT=IMG_HEIGHT, IMG_WIDTH=IMG_WIDTH, IMG_CHANNELS=IMG_CHANNELS)

model = get_model()
model.compile(optimizer='adam', loss=total_loss, metrics=metrics)
#model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=metrics)
model.summary()


history1 = model.fit(X_train, y_train,
                    batch_size = 16,
                    verbose=1,
                    epochs=100,
                    validation_data=(X_test, y_test),
                    shuffle=False)
history = history1
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['jacard_coef']
val_acc = history.history['val_jacard_coef']

plt.plot(epochs, acc, 'y', label='Training IoU')
plt.plot(epochs, val_acc, 'r', label='Validation IoU')
plt.title('Training and validation IoU')
plt.xlabel('Epochs')
plt.ylabel('IoU')
plt.legend()
plt.show()


##################################


#IOU
y_pred=model.predict(X_test)
y_pred_argmax=np.argmax(y_pred, axis=3)
y_test_argmax=np.argmax(y_test, axis=3)


#Using built in keras function for IoU
from keras.metrics import MeanIoU
n_classes = 6
IOU_keras = MeanIoU(num_classes=n_classes)
IOU_keras.update_state(y_test_argmax, y_pred_argmax)
print("Mean IoU =", IOU_keras.result().numpy())

#######################################################################
#Predict on a few images

import random
test_img_number = random.randint(0, len(X_test))
test_img = X_test[test_img_number]
ground_truth=y_test_argmax[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
prediction = (model.predict(test_img_input))
predicted_img=np.argmax(prediction, axis=3)[0,:,:]


plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img)
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth)
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(predicted_img)
plt.show()

import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# Define the color-to-class mapping
color_to_class = {
    (60, 16, 152): 0,  # Building
    (132, 41, 246): 1,  # Land
    (110, 193, 228): 2,  # Road
    (254, 221, 58): 3,  # Vegetation
    (226, 169, 41): 4,  # Water
    (155, 155, 155): 5   # Unlabeled
}

def convert_color_to_class(segmented_image):
    """
    Convert color image to class labels based on predefined color-to-class mapping.

    Parameters:
    segmented_image (np.array): Segmented image array.

    Returns:
    class_labels (np.array): Array of class labels.
    """
    # Initialize the class labels array
    class_labels = np.zeros(segmented_image.shape[:2], dtype=int)

    # Iterate over the color-to-class mapping
    for color, class_label in color_to_class.items():
        # Convert the color to a numpy array
        color_array = np.array(color).reshape(1, 1, 3)
        # Create a mask for the current color
        mask = np.all(segmented_image == color_array, axis=-1)
        # Apply the mask to the class labels array
        class_labels[mask] = class_label

    return class_labels

def calculate_area(class_labels, pixel_area=1):
    """
    Calculate the area of each class.

    Parameters:
    class_labels (np.array): Array of class labels.
    pixel_area (float): Area represented by each pixel. Default is 1.

    Returns:
    area_dict (dict): Dictionary with class labels as keys and corresponding areas as values.
    """
    unique_classes, counts = np.unique(class_labels, return_counts=True)
    area_dict = {cls: count * pixel_area for cls, count in zip(unique_classes, counts)}
    return area_dict

test_img_number = np.random.randint(0, len(X_test))
test_img = X_test[test_img_number]
test_img_input = np.expand_dims(test_img, 0)

# Predict the segmented output
prediction = model.predict(test_img_input)
predicted_img = np.argmax(prediction, axis=3)[0]

# Convert the predicted image to RGB format for visualization (assuming it is in label format)
# This step is necessary if your prediction output is in label format and you want to visualize it
label_to_color = {v: k for k, v in color_to_class.items()}
predicted_img_rgb = np.zeros((*predicted_img.shape, 3), dtype=np.uint8)
for label, color in label_to_color.items():
    predicted_img_rgb[predicted_img == label] = color

# Convert the RGB image to class labels
class_labels = convert_color_to_class(predicted_img_rgb)

# Calculate the area for each class
area_dict = calculate_area(class_labels)
print("Area for each class:", area_dict)
# Out:
# Now patchifying image: /content/changedtest/Semantic segmentation dataset/Tile 1/images/image_part_003.jpg
# Now patchifying image: /content/changedtest/Semantic segmentation dataset/Tile 1/images/image_part_005.jpg
# Now patchifying image: /content/changedtest/Semantic segmentation dataset/Tile 1/images/image_part_001.jpg
# Now patchifying image: /content/changedtest/Semantic segmentation dataset/Tile 1/images/image_part_004.jpg
# Now patchifying image: /content/changedtest/Semantic segmentation dataset/Tile 1/images/image_part_002.jpg
# Now patchifying image: /content/changedtest/Semantic segmentation dataset/Tile 1/images/image_part_006.jpg
# Now patchifying image: /content/changedtest/Semantic segmentation dataset/Tile 1/images/image_part_007.jpg
# Now patchifying image: /content/changedtest/Semantic segmentation dataset/Tile 1/images/image_part_008.jpg
# Now patchifying image: /content/changedtest/Semantic segmentation dataset/Tile 1/images/image_part_009.jpg
# Now patchifying image: /content/changedtest/Semantic segmentation dataset/Tile 8/images/image_part_003.jpg
# Now patchifying image: /content/changedtest/Semantic segmentation dataset/Tile 8/images/image_part_005.jpg
# Now patchifying image: /content/changedtest/Semantic segmentation dataset/Tile 8/images/image_part_001.jpg
# Now patchifying image: /content/changedtest/Semantic segmentation dataset/Tile 8/images/image_part_004.jpg
# Now patchifying image: /content/changedtest/Semantic segmentation dataset/Tile 8/images/image_part_002.jpg
# Now patchifying image: /content/changedtest/Semantic segmentation dataset/Tile 8/images/image_part_006.jpg
# Now patchifying image: /content/changedtest/Semantic segmentation dataset/Tile 8/images/image_part_007.jpg
# Now patchifying image: /content/changedtest/Semantic segmentation dataset/Tile 8/images/image_part_008.jpg
# Now patchifying image: /content/changedtest/Semantic segmentation dataset/Tile 8/images/image_part_009.jpg
# Now patchifying image: /content/changedtest/Semantic segmentation dataset/Tile 3/images/image_part_003.jpg
# Now patchifying image: /content/changedtest/Semantic segmentation dataset/Tile 3/images/image_part_005.jpg
# Now patchifying image: /content/changedtest/Semantic segmentation dataset/Tile 3/images/image_part_001.jpg
# Now patchifying image: /content/changedtest/Semantic segmentation dataset/Tile 3/images/image_part_004.jpg
# Now patchifying image: /content/changedtest/Semantic segmentation dataset/Tile 3/images/image_part_002.jpg
# Now patchifying image: /content/changedtest/Semantic segmentation dataset/Tile 3/images/image_part_006.jpg
# Now patchifying image: /content/changedtest/Semantic segmentation dataset/Tile 3/images/image_part_007.jpg
# Now patchifying image: /content/changedtest/Semantic segmentation dataset/Tile 3/images/image_part_008.jpg
# Now patchifying image: /content/changedtest/Semantic segmentation dataset/Tile 3/images/image_part_009.jpg
# Now patchifying image: /content/changedtest/Semantic segmentation dataset/Tile 2/images/image_part_003.jpg
# Now patchifying image: /content/changedtest/Semantic segmentation dataset/Tile 2/images/image_part_005.jpg
# Now patchifying image: /content/changedtest/Semantic segmentation dataset/Tile 2/images/image_part_001.jpg
# Now patchifying image: /content/changedtest/Semantic segmentation dataset/Tile 2/images/image_part_004.jpg
# Now patchifying image: /content/changedtest/Semantic segmentation dataset/Tile 2/images/image_part_002.jpg
# Now patchifying image: /content/changedtest/Semantic segmentation dataset/Tile 2/images/image_part_006.jpg
# Now patchifying image: /content/changedtest/Semantic segmentation dataset/Tile 2/images/image_part_007.jpg
# Now patchifying image: /content/changedtest/Semantic segmentation dataset/Tile 2/images/image_part_008.jpg
# Now patchifying image: /content/changedtest/Semantic segmentation dataset/Tile 2/images/image_part_009.jpg
# Now patchifying mask: /content/changedtest/Semantic segmentation dataset/Tile 1/masks/image_part_008.png
# Now patchifying mask: /content/changedtest/Semantic segmentation dataset/Tile 1/masks/image_part_002.png
# Now patchifying mask: /content/changedtest/Semantic segmentation dataset/Tile 1/masks/image_part_001.png
# Now patchifying mask: /content/changedtest/Semantic segmentation dataset/Tile 1/masks/image_part_003.png
# Now patchifying mask: /content/changedtest/Semantic segmentation dataset/Tile 1/masks/image_part_007.png
# Now patchifying mask: /content/changedtest/Semantic segmentation dataset/Tile 1/masks/image_part_009.png
# Now patchifying mask: /content/changedtest/Semantic segmentation dataset/Tile 1/masks/image_part_004.png
# Now patchifying mask: /content/changedtest/Semantic segmentation dataset/Tile 1/masks/image_part_005.png
# Now patchifying mask: /content/changedtest/Semantic segmentation dataset/Tile 1/masks/image_part_006.png
# Now patchifying mask: /content/changedtest/Semantic segmentation dataset/Tile 8/masks/image_part_008.png
# Now patchifying mask: /content/changedtest/Semantic segmentation dataset/Tile 8/masks/image_part_002.png
# Now patchifying mask: /content/changedtest/Semantic segmentation dataset/Tile 8/masks/image_part_001.png
# Now patchifying mask: /content/changedtest/Semantic segmentation dataset/Tile 8/masks/image_part_003.png
# Now patchifying mask: /content/changedtest/Semantic segmentation dataset/Tile 8/masks/image_part_007.png
# Now patchifying mask: /content/changedtest/Semantic segmentation dataset/Tile 8/masks/image_part_009.png
# Now patchifying mask: /content/changedtest/Semantic segmentation dataset/Tile 8/masks/image_part_004.png
# Now patchifying mask: /content/changedtest/Semantic segmentation dataset/Tile 8/masks/image_part_005.png
# Now patchifying mask: /content/changedtest/Semantic segmentation dataset/Tile 8/masks/image_part_006.png
# Now patchifying mask: /content/changedtest/Semantic segmentation dataset/Tile 3/masks/image_part_008.png
# Now patchifying mask: /content/changedtest/Semantic segmentation dataset/Tile 3/masks/image_part_002.png
# Now patchifying mask: /content/changedtest/Semantic segmentation dataset/Tile 3/masks/image_part_001.png
# Now patchifying mask: /content/changedtest/Semantic segmentation dataset/Tile 3/masks/image_part_003.png
# Now patchifying mask: /content/changedtest/Semantic segmentation dataset/Tile 3/masks/image_part_007.png
# Now patchifying mask: /content/changedtest/Semantic segmentation dataset/Tile 3/masks/image_part_009.png
# Now patchifying mask: /content/changedtest/Semantic segmentation dataset/Tile 3/masks/image_part_004.png
# Now patchifying mask: /content/changedtest/Semantic segmentation dataset/Tile 3/masks/image_part_005.png
# Now patchifying mask: /content/changedtest/Semantic segmentation dataset/Tile 3/masks/image_part_006.png
# Now patchifying mask: /content/changedtest/Semantic segmentation dataset/Tile 2/masks/image_part_008.png
# Now patchifying mask: /content/changedtest/Semantic segmentation dataset/Tile 2/masks/image_part_002.png
# Now patchifying mask: /content/changedtest/Semantic segmentation dataset/Tile 2/masks/image_part_001.png
# Now patchifying mask: /content/changedtest/Semantic segmentation dataset/Tile 2/masks/image_part_003.png
# Now patchifying mask: /content/changedtest/Semantic segmentation dataset/Tile 2/masks/image_part_007.png
# Now patchifying mask: /content/changedtest/Semantic segmentation dataset/Tile 2/masks/image_part_009.png
# Now patchifying mask: /content/changedtest/Semantic segmentation dataset/Tile 2/masks/image_part_004.png
# Now patchifying mask: /content/changedtest/Semantic segmentation dataset/Tile 2/masks/image_part_005.png
# Now patchifying mask: /content/changedtest/Semantic segmentation dataset/Tile 2/masks/image_part_006.png
# 60
# Unique labels in label dataset are:  [0 1 2 3 4 5]
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv2d_19 (Conv2D)          (None, 256, 256, 16)         448       ['input_2[0][0]']
#
#  dropout_9 (Dropout)         (None, 256, 256, 16)         0         ['conv2d_19[0][0]']
#
#  conv2d_20 (Conv2D)          (None, 256, 256, 16)         2320      ['dropout_9[0][0]']
#
#  max_pooling2d_4 (MaxPoolin  (None, 128, 128, 16)         0         ['conv2d_20[0][0]']
#  g2D)
#
#  conv2d_21 (Conv2D)          (None, 128, 128, 32)         4640      ['max_pooling2d_4[0][0]']
#
#  dropout_10 (Dropout)        (None, 128, 128, 32)         0         ['conv2d_21[0][0]']
#
#  conv2d_22 (Conv2D)          (None, 128, 128, 32)         9248      ['dropout_10[0][0]']
#
#  max_pooling2d_5 (MaxPoolin  (None, 64, 64, 32)           0         ['conv2d_22[0][0]']
#  g2D)
#
#  conv2d_23 (Conv2D)          (None, 64, 64, 64)           18496     ['max_pooling2d_5[0][0]']
#
#  dropout_11 (Dropout)        (None, 64, 64, 64)           0         ['conv2d_23[0][0]']
#
#  conv2d_24 (Conv2D)          (None, 64, 64, 64)           36928     ['dropout_11[0][0]']
#
#  max_pooling2d_6 (MaxPoolin  (None, 32, 32, 64)           0         ['conv2d_24[0][0]']
#  g2D)
#
#  conv2d_25 (Conv2D)          (None, 32, 32, 128)          73856     ['max_pooling2d_6[0][0]']
#
#  dropout_12 (Dropout)        (None, 32, 32, 128)          0         ['conv2d_25[0][0]']
#
#  conv2d_26 (Conv2D)          (None, 32, 32, 128)          147584    ['dropout_12[0][0]']
#
#  max_pooling2d_7 (MaxPoolin  (None, 16, 16, 128)          0         ['conv2d_26[0][0]']
#  g2D)
#
#  conv2d_27 (Conv2D)          (None, 16, 16, 256)          295168    ['max_pooling2d_7[0][0]']
#
#  dropout_13 (Dropout)        (None, 16, 16, 256)          0         ['conv2d_27[0][0]']
#
#  conv2d_28 (Conv2D)          (None, 16, 16, 256)          590080    ['dropout_13[0][0]']
#
#  conv2d_transpose_4 (Conv2D  (None, 32, 32, 128)          131200    ['conv2d_28[0][0]']
#  Transpose)
#
#  concatenate_4 (Concatenate  (None, 32, 32, 256)          0         ['conv2d_transpose_4[0][0]',
#  )                                                                   'conv2d_26[0][0]']
#
#  conv2d_29 (Conv2D)          (None, 32, 32, 128)          295040    ['concatenate_4[0][0]']
#
#  dropout_14 (Dropout)        (None, 32, 32, 128)          0         ['conv2d_29[0][0]']
#
#  conv2d_30 (Conv2D)          (None, 32, 32, 128)          147584    ['dropout_14[0][0]']
#
#  conv2d_transpose_5 (Conv2D  (None, 64, 64, 64)           32832     ['conv2d_30[0][0]']
#  Transpose)
#
#  concatenate_5 (Concatenate  (None, 64, 64, 128)          0         ['conv2d_transpose_5[0][0]',
#  )                                                                   'conv2d_24[0][0]']
#
#  conv2d_31 (Conv2D)          (None, 64, 64, 64)           73792     ['concatenate_5[0][0]']
#
#  dropout_15 (Dropout)        (None, 64, 64, 64)           0         ['conv2d_31[0][0]']
#
#  conv2d_32 (Conv2D)          (None, 64, 64, 64)           36928     ['dropout_15[0][0]']
#
#  conv2d_transpose_6 (Conv2D  (None, 128, 128, 32)         8224      ['conv2d_32[0][0]']
#  Transpose)
#
#  concatenate_6 (Concatenate  (None, 128, 128, 64)         0         ['conv2d_transpose_6[0][0]',
#  )                                                                   'conv2d_22[0][0]']
#
#  conv2d_33 (Conv2D)          (None, 128, 128, 32)         18464     ['concatenate_6[0][0]']
#
#  dropout_16 (Dropout)        (None, 128, 128, 32)         0         ['conv2d_33[0][0]']
#
#  conv2d_34 (Conv2D)          (None, 128, 128, 32)         9248      ['dropout_16[0][0]']
#
#  conv2d_transpose_7 (Conv2D  (None, 256, 256, 16)         2064      ['conv2d_34[0][0]']
#  Transpose)
#
#  concatenate_7 (Concatenate  (None, 256, 256, 32)         0         ['conv2d_transpose_7[0][0]',
#  )                                                                   'conv2d_20[0][0]']
#
#  conv2d_35 (Conv2D)          (None, 256, 256, 16)         4624      ['concatenate_7[0][0]']
#
#  dropout_17 (Dropout)        (None, 256, 256, 16)         0         ['conv2d_35[0][0]']
#
#  conv2d_36 (Conv2D)          (None, 256, 256, 16)         2320      ['dropout_17[0][0]']
#
#  conv2d_37 (Conv2D)          (None, 256, 256, 6)          102       ['conv2d_36[0][0]']
#
# ==================================================================================================
# Total params: 1941190 (7.41 MB)
# Trainable params: 1941190 (7.41 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/100
# 24/24 [==============================] - 38s 670ms/step - loss: 1.0178 - accuracy: 0.4395 - jacard_coef: 0.1507 - val_loss: 1.0138 - val_accuracy: 0.4821 - val_jacard_coef: 0.1362
# Epoch 2/100
# 24/24 [==============================] - 5s 215ms/step - loss: 1.0132 - accuracy: 0.4698 - jacard_coef: 0.1596 - val_loss: 1.0126 - val_accuracy: 0.4826 - val_jacard_coef: 0.1380
# Epoch 3/100
# 24/24 [==============================] - 5s 209ms/step - loss: 1.0121 - accuracy: 0.4724 - jacard_coef: 0.1608 - val_loss: 1.0119 - val_accuracy: 0.4826 - val_jacard_coef: 0.1388
# Epoch 4/100
# 24/24 [==============================] - 5s 226ms/step - loss: 1.0114 - accuracy: 0.4725 - jacard_coef: 0.1609 - val_loss: 1.0110 - val_accuracy: 0.4826 - val_jacard_coef: 0.1425
# Epoch 5/100
# 24/24 [==============================] - 5s 210ms/step - loss: 1.0110 - accuracy: 0.4728 - jacard_coef: 0.1607 - val_loss: 1.0103 - val_accuracy: 0.4826 - val_jacard_coef: 0.1462
# Epoch 6/100
# 24/24 [==============================] - 5s 210ms/step - loss: 1.0107 - accuracy: 0.4730 - jacard_coef: 0.1606 - val_loss: 1.0100 - val_accuracy: 0.4826 - val_jacard_coef: 0.1489
# Epoch 7/100
# 24/24 [==============================] - 5s 215ms/step - loss: 1.0105 - accuracy: 0.4734 - jacard_coef: 0.1612 - val_loss: 1.0097 - val_accuracy: 0.4826 - val_jacard_coef: 0.1507
# Epoch 8/100
# 24/24 [==============================] - 5s 213ms/step - loss: 1.0103 - accuracy: 0.4733 - jacard_coef: 0.1614 - val_loss: 1.0095 - val_accuracy: 0.4826 - val_jacard_coef: 0.1511
# Epoch 9/100
# 24/24 [==============================] - 5s 219ms/step - loss: 1.0101 - accuracy: 0.4733 - jacard_coef: 0.1618 - val_loss: 1.0093 - val_accuracy: 0.4826 - val_jacard_coef: 0.1514
# Epoch 10/100
# 24/24 [==============================] - 5s 212ms/step - loss: 1.0100 - accuracy: 0.4733 - jacard_coef: 0.1620 - val_loss: 1.0092 - val_accuracy: 0.4826 - val_jacard_coef: 0.1519
# Epoch 11/100
# 24/24 [==============================] - 5s 212ms/step - loss: 1.0098 - accuracy: 0.4734 - jacard_coef: 0.1621 - val_loss: 1.0090 - val_accuracy: 0.4826 - val_jacard_coef: 0.1538
# Epoch 12/100
# 24/24 [==============================] - 5s 220ms/step - loss: 1.0095 - accuracy: 0.4735 - jacard_coef: 0.1627 - val_loss: 1.0087 - val_accuracy: 0.4826 - val_jacard_coef: 0.1562
# Epoch 13/100
# 24/24 [==============================] - 5s 217ms/step - loss: 1.0091 - accuracy: 0.4735 - jacard_coef: 0.1639 - val_loss: 1.0083 - val_accuracy: 0.4818 - val_jacard_coef: 0.1574
# Epoch 14/100
# 24/24 [==============================] - 5s 221ms/step - loss: 1.0084 - accuracy: 0.4723 - jacard_coef: 0.1660 - val_loss: 1.0074 - val_accuracy: 0.4780 - val_jacard_coef: 0.1626
# Epoch 15/100
# 24/24 [==============================] - 5s 215ms/step - loss: 1.0091 - accuracy: 0.4702 - jacard_coef: 0.1637 - val_loss: 1.0073 - val_accuracy: 0.4730 - val_jacard_coef: 0.1585
# Epoch 16/100
# 24/24 [==============================] - 5s 216ms/step - loss: 1.0078 - accuracy: 0.4696 - jacard_coef: 0.1677 - val_loss: 1.0074 - val_accuracy: 0.4750 - val_jacard_coef: 0.1628
# Epoch 17/100
# 24/24 [==============================] - 5s 217ms/step - loss: 1.0077 - accuracy: 0.4693 - jacard_coef: 0.1678 - val_loss: 1.0070 - val_accuracy: 0.4748 - val_jacard_coef: 0.1635
# Epoch 18/100
# 24/24 [==============================] - 5s 212ms/step - loss: 1.0074 - accuracy: 0.4695 - jacard_coef: 0.1682 - val_loss: 1.0071 - val_accuracy: 0.4748 - val_jacard_coef: 0.1645
# Epoch 19/100
# 24/24 [==============================] - 5s 216ms/step - loss: 1.0073 - accuracy: 0.4690 - jacard_coef: 0.1691 - val_loss: 1.0075 - val_accuracy: 0.4732 - val_jacard_coef: 0.1628
# Epoch 20/100
# 24/24 [==============================] - 5s 210ms/step - loss: 1.0073 - accuracy: 0.4679 - jacard_coef: 0.1690 - val_loss: 1.0070 - val_accuracy: 0.4740 - val_jacard_coef: 0.1623
# Epoch 21/100
# 24/24 [==============================] - 5s 217ms/step - loss: 1.0071 - accuracy: 0.4672 - jacard_coef: 0.1693 - val_loss: 1.0067 - val_accuracy: 0.4740 - val_jacard_coef: 0.1645
# Epoch 22/100
# 24/24 [==============================] - 5s 212ms/step - loss: 1.0069 - accuracy: 0.4670 - jacard_coef: 0.1697 - val_loss: 1.0065 - val_accuracy: 0.4741 - val_jacard_coef: 0.1653
# Epoch 23/100
# 24/24 [==============================] - 5s 212ms/step - loss: 1.0068 - accuracy: 0.4666 - jacard_coef: 0.1709 - val_loss: 1.0064 - val_accuracy: 0.4674 - val_jacard_coef: 0.1650
# Epoch 24/100
# 24/24 [==============================] - 5s 217ms/step - loss: 1.0068 - accuracy: 0.4640 - jacard_coef: 0.1700 - val_loss: 1.0064 - val_accuracy: 0.4651 - val_jacard_coef: 0.1669
# Epoch 25/100
# 24/24 [==============================] - 5s 210ms/step - loss: 1.0067 - accuracy: 0.4631 - jacard_coef: 0.1700 - val_loss: 1.0060 - val_accuracy: 0.4674 - val_jacard_coef: 0.1677
# Epoch 26/100
# 24/24 [==============================] - 5s 218ms/step - loss: 1.0065 - accuracy: 0.4639 - jacard_coef: 0.1712 - val_loss: 1.0063 - val_accuracy: 0.4647 - val_jacard_coef: 0.1677
# Epoch 27/100
# 24/24 [==============================] - 5s 212ms/step - loss: 1.0065 - accuracy: 0.4645 - jacard_coef: 0.1713 - val_loss: 1.0063 - val_accuracy: 0.4627 - val_jacard_coef: 0.1686
# Epoch 28/100
# 24/24 [==============================] - 5s 213ms/step - loss: 1.0065 - accuracy: 0.4632 - jacard_coef: 0.1710 - val_loss: 1.0061 - val_accuracy: 0.4643 - val_jacard_coef: 0.1685
# Epoch 29/100
# 24/24 [==============================] - 5s 218ms/step - loss: 1.0062 - accuracy: 0.4623 - jacard_coef: 0.1719 - val_loss: 1.0060 - val_accuracy: 0.4676 - val_jacard_coef: 0.1697
# Epoch 30/100
# 24/24 [==============================] - 5s 213ms/step - loss: 1.0061 - accuracy: 0.4642 - jacard_coef: 0.1722 - val_loss: 1.0060 - val_accuracy: 0.4654 - val_jacard_coef: 0.1699
# Epoch 31/100
# 24/24 [==============================] - 5s 217ms/step - loss: 1.0059 - accuracy: 0.4672 - jacard_coef: 0.1730 - val_loss: 1.0064 - val_accuracy: 0.4672 - val_jacard_coef: 0.1709
# Epoch 32/100
# 24/24 [==============================] - 5s 213ms/step - loss: 1.0063 - accuracy: 0.4670 - jacard_coef: 0.1722 - val_loss: 1.0056 - val_accuracy: 0.4690 - val_jacard_coef: 0.1708
# Epoch 33/100
# 24/24 [==============================] - 5s 228ms/step - loss: 1.0057 - accuracy: 0.4680 - jacard_coef: 0.1742 - val_loss: 1.0059 - val_accuracy: 0.4693 - val_jacard_coef: 0.1710
# Epoch 34/100
# 24/24 [==============================] - 5s 215ms/step - loss: 1.0057 - accuracy: 0.4671 - jacard_coef: 0.1732 - val_loss: 1.0068 - val_accuracy: 0.4613 - val_jacard_coef: 0.1720
# Epoch 35/100
# 24/24 [==============================] - 5s 212ms/step - loss: 1.0057 - accuracy: 0.4694 - jacard_coef: 0.1750 - val_loss: 1.0051 - val_accuracy: 0.4764 - val_jacard_coef: 0.1721
# Epoch 36/100
# 24/24 [==============================] - 5s 216ms/step - loss: 1.0052 - accuracy: 0.4712 - jacard_coef: 0.1753 - val_loss: 1.0056 - val_accuracy: 0.4710 - val_jacard_coef: 0.1726
# Epoch 37/100
# 24/24 [==============================] - 5s 211ms/step - loss: 1.0052 - accuracy: 0.4707 - jacard_coef: 0.1754 - val_loss: 1.0059 - val_accuracy: 0.4708 - val_jacard_coef: 0.1729
# Epoch 38/100
# 24/24 [==============================] - 5s 215ms/step - loss: 1.0051 - accuracy: 0.4728 - jacard_coef: 0.1777 - val_loss: 1.0054 - val_accuracy: 0.4752 - val_jacard_coef: 0.1724
# Epoch 39/100
# 24/24 [==============================] - 5s 219ms/step - loss: 1.0048 - accuracy: 0.4727 - jacard_coef: 0.1763 - val_loss: 1.0055 - val_accuracy: 0.4742 - val_jacard_coef: 0.1754
# Epoch 40/100
# 24/24 [==============================] - 5s 211ms/step - loss: 1.0049 - accuracy: 0.4747 - jacard_coef: 0.1774 - val_loss: 1.0048 - val_accuracy: 0.4811 - val_jacard_coef: 0.1764
# Epoch 41/100
# 24/24 [==============================] - 5s 215ms/step - loss: 1.0047 - accuracy: 0.4730 - jacard_coef: 0.1768 - val_loss: 1.0061 - val_accuracy: 0.4716 - val_jacard_coef: 0.1741
# Epoch 42/100
# 24/24 [==============================] - 5s 210ms/step - loss: 1.0051 - accuracy: 0.4723 - jacard_coef: 0.1779 - val_loss: 1.0056 - val_accuracy: 0.4712 - val_jacard_coef: 0.1734
# Epoch 43/100
# 24/24 [==============================] - 5s 214ms/step - loss: 1.0049 - accuracy: 0.4718 - jacard_coef: 0.1764 - val_loss: 1.0064 - val_accuracy: 0.4656 - val_jacard_coef: 0.1755
# Epoch 44/100
# 24/24 [==============================] - 5s 210ms/step - loss: 1.0049 - accuracy: 0.4775 - jacard_coef: 0.1782 - val_loss: 1.0049 - val_accuracy: 0.4841 - val_jacard_coef: 0.1758
# Epoch 45/100
# 24/24 [==============================] - 5s 208ms/step - loss: 1.0051 - accuracy: 0.4752 - jacard_coef: 0.1763 - val_loss: 1.0061 - val_accuracy: 0.4643 - val_jacard_coef: 0.1757
# Epoch 46/100
# 24/24 [==============================] - 5s 216ms/step - loss: 1.0046 - accuracy: 0.4758 - jacard_coef: 0.1798 - val_loss: 1.0045 - val_accuracy: 0.4804 - val_jacard_coef: 0.1756
# Epoch 47/100
# 24/24 [==============================] - 5s 211ms/step - loss: 1.0045 - accuracy: 0.4748 - jacard_coef: 0.1769 - val_loss: 1.0063 - val_accuracy: 0.4682 - val_jacard_coef: 0.1763
# Epoch 48/100
# 24/24 [==============================] - 5s 215ms/step - loss: 1.0042 - accuracy: 0.4779 - jacard_coef: 0.1808 - val_loss: 1.0050 - val_accuracy: 0.4764 - val_jacard_coef: 0.1743
# Epoch 49/100
# 24/24 [==============================] - 5s 212ms/step - loss: 1.0043 - accuracy: 0.4729 - jacard_coef: 0.1791 - val_loss: 1.0060 - val_accuracy: 0.4726 - val_jacard_coef: 0.1757
# Epoch 50/100
# 24/24 [==============================] - 5s 208ms/step - loss: 1.0039 - accuracy: 0.4810 - jacard_coef: 0.1811 - val_loss: 1.0074 - val_accuracy: 0.4690 - val_jacard_coef: 0.1716
# Epoch 51/100
# 24/24 [==============================] - 5s 215ms/step - loss: 1.0038 - accuracy: 0.4784 - jacard_coef: 0.1807 - val_loss: 1.0077 - val_accuracy: 0.4690 - val_jacard_coef: 0.1720
# Epoch 52/100
# 24/24 [==============================] - 5s 210ms/step - loss: 1.0038 - accuracy: 0.4798 - jacard_coef: 0.1826 - val_loss: 1.0061 - val_accuracy: 0.4714 - val_jacard_coef: 0.1712
# Epoch 53/100
# 24/24 [==============================] - 5s 216ms/step - loss: 1.0035 - accuracy: 0.4739 - jacard_coef: 0.1816 - val_loss: 1.0066 - val_accuracy: 0.4654 - val_jacard_coef: 0.1702
# Epoch 54/100
# 24/24 [==============================] - 5s 209ms/step - loss: 1.0035 - accuracy: 0.4769 - jacard_coef: 0.1824 - val_loss: 1.0097 - val_accuracy: 0.4616 - val_jacard_coef: 0.1685
# Epoch 55/100
# 24/24 [==============================] - 5s 209ms/step - loss: 1.0034 - accuracy: 0.4794 - jacard_coef: 0.1832 - val_loss: 1.0111 - val_accuracy: 0.4566 - val_jacard_coef: 0.1663
# Epoch 56/100
# 24/24 [==============================] - 5s 216ms/step - loss: 1.0042 - accuracy: 0.4773 - jacard_coef: 0.1797 - val_loss: 1.0056 - val_accuracy: 0.4792 - val_jacard_coef: 0.1723
# Epoch 57/100
# 24/24 [==============================] - 5s 210ms/step - loss: 1.0040 - accuracy: 0.4740 - jacard_coef: 0.1809 - val_loss: 1.0067 - val_accuracy: 0.4691 - val_jacard_coef: 0.1701
# Epoch 58/100
# 24/24 [==============================] - 5s 212ms/step - loss: 1.0033 - accuracy: 0.4773 - jacard_coef: 0.1822 - val_loss: 1.0069 - val_accuracy: 0.4662 - val_jacard_coef: 0.1710
# Epoch 59/100
# 24/24 [==============================] - 5s 209ms/step - loss: 1.0033 - accuracy: 0.4743 - jacard_coef: 0.1816 - val_loss: 1.0108 - val_accuracy: 0.4584 - val_jacard_coef: 0.1660
# Epoch 60/100
# 24/24 [==============================] - 5s 211ms/step - loss: 1.0034 - accuracy: 0.4786 - jacard_coef: 0.1837 - val_loss: 1.0060 - val_accuracy: 0.4704 - val_jacard_coef: 0.1714
# Epoch 61/100
# 24/24 [==============================] - 5s 214ms/step - loss: 1.0029 - accuracy: 0.4773 - jacard_coef: 0.1835 - val_loss: 1.0061 - val_accuracy: 0.4698 - val_jacard_coef: 0.1722
# Epoch 62/100
# 24/24 [==============================] - 5s 212ms/step - loss: 1.0026 - accuracy: 0.4781 - jacard_coef: 0.1844 - val_loss: 1.0071 - val_accuracy: 0.4720 - val_jacard_coef: 0.1708
# Epoch 63/100
# 24/24 [==============================] - 5s 215ms/step - loss: 1.0020 - accuracy: 0.4810 - jacard_coef: 0.1869 - val_loss: 1.0067 - val_accuracy: 0.4715 - val_jacard_coef: 0.1752
# Epoch 64/100
# 24/24 [==============================] - 5s 210ms/step - loss: 1.0025 - accuracy: 0.4768 - jacard_coef: 0.1869 - val_loss: 1.0065 - val_accuracy: 0.4711 - val_jacard_coef: 0.1727
# Epoch 65/100
# 24/24 [==============================] - 5s 211ms/step - loss: 1.0024 - accuracy: 0.4747 - jacard_coef: 0.1826 - val_loss: 1.0076 - val_accuracy: 0.4643 - val_jacard_coef: 0.1773
# Epoch 66/100
# 24/24 [==============================] - 5s 213ms/step - loss: 1.0019 - accuracy: 0.4808 - jacard_coef: 0.1875 - val_loss: 1.0049 - val_accuracy: 0.4786 - val_jacard_coef: 0.1769
# Epoch 67/100
# 24/24 [==============================] - 5s 211ms/step - loss: 1.0023 - accuracy: 0.4755 - jacard_coef: 0.1835 - val_loss: 1.0076 - val_accuracy: 0.4667 - val_jacard_coef: 0.1752
# Epoch 68/100
# 24/24 [==============================] - 5s 218ms/step - loss: 1.0028 - accuracy: 0.4797 - jacard_coef: 0.1869 - val_loss: 1.0060 - val_accuracy: 0.4766 - val_jacard_coef: 0.1820
# Epoch 69/100
# 24/24 [==============================] - 5s 206ms/step - loss: 1.0036 - accuracy: 0.4762 - jacard_coef: 0.1806 - val_loss: 1.0063 - val_accuracy: 0.4690 - val_jacard_coef: 0.1734
# Epoch 70/100
# 24/24 [==============================] - 5s 212ms/step - loss: 1.0026 - accuracy: 0.4783 - jacard_coef: 0.1854 - val_loss: 1.0072 - val_accuracy: 0.4731 - val_jacard_coef: 0.1796
# Epoch 71/100
# 24/24 [==============================] - 5s 212ms/step - loss: 1.0021 - accuracy: 0.4844 - jacard_coef: 0.1864 - val_loss: 1.0056 - val_accuracy: 0.4671 - val_jacard_coef: 0.1786
# Epoch 72/100
# 24/24 [==============================] - 5s 208ms/step - loss: 1.0018 - accuracy: 0.4822 - jacard_coef: 0.1881 - val_loss: 1.0059 - val_accuracy: 0.4766 - val_jacard_coef: 0.1795
# Epoch 73/100
# 24/24 [==============================] - 5s 216ms/step - loss: 1.0011 - accuracy: 0.4828 - jacard_coef: 0.1902 - val_loss: 1.0086 - val_accuracy: 0.4706 - val_jacard_coef: 0.1789
# Epoch 74/100
# 24/24 [==============================] - 5s 208ms/step - loss: 1.0003 - accuracy: 0.4892 - jacard_coef: 0.1930 - val_loss: 1.0062 - val_accuracy: 0.4753 - val_jacard_coef: 0.1828
# Epoch 75/100
# 24/24 [==============================] - 5s 213ms/step - loss: 0.9999 - accuracy: 0.4882 - jacard_coef: 0.1942 - val_loss: 1.0078 - val_accuracy: 0.4741 - val_jacard_coef: 0.1798
# Epoch 76/100
# 24/24 [==============================] - 5s 211ms/step - loss: 0.9995 - accuracy: 0.4863 - jacard_coef: 0.1959 - val_loss: 1.0066 - val_accuracy: 0.4812 - val_jacard_coef: 0.1816
# Epoch 77/100
# 24/24 [==============================] - 5s 210ms/step - loss: 0.9996 - accuracy: 0.4878 - jacard_coef: 0.1938 - val_loss: 1.0055 - val_accuracy: 0.4829 - val_jacard_coef: 0.1857
# Epoch 78/100
# 24/24 [==============================] - 5s 214ms/step - loss: 0.9997 - accuracy: 0.4895 - jacard_coef: 0.1957 - val_loss: 1.0070 - val_accuracy: 0.4772 - val_jacard_coef: 0.1821
# Epoch 79/100
# 24/24 [==============================] - 5s 209ms/step - loss: 0.9993 - accuracy: 0.4931 - jacard_coef: 0.1996 - val_loss: 1.0062 - val_accuracy: 0.4778 - val_jacard_coef: 0.1919
# Epoch 80/100
# 24/24 [==============================] - 5s 212ms/step - loss: 1.0021 - accuracy: 0.4711 - jacard_coef: 0.1847 - val_loss: 1.0060 - val_accuracy: 0.4753 - val_jacard_coef: 0.1784
# Epoch 81/100
# 24/24 [==============================] - 5s 211ms/step - loss: 1.0003 - accuracy: 0.4896 - jacard_coef: 0.1952 - val_loss: 1.0058 - val_accuracy: 0.4753 - val_jacard_coef: 0.1809
# Epoch 82/100
# 24/24 [==============================] - 5s 211ms/step - loss: 0.9994 - accuracy: 0.4892 - jacard_coef: 0.1954 - val_loss: 1.0113 - val_accuracy: 0.4702 - val_jacard_coef: 0.1778
# Epoch 83/100
# 24/24 [==============================] - 5s 213ms/step - loss: 1.0010 - accuracy: 0.4853 - jacard_coef: 0.1929 - val_loss: 1.0076 - val_accuracy: 0.4518 - val_jacard_coef: 0.1763
# Epoch 84/100
# 24/24 [==============================] - 5s 209ms/step - loss: 0.9992 - accuracy: 0.4885 - jacard_coef: 0.1964 - val_loss: 1.0064 - val_accuracy: 0.4699 - val_jacard_coef: 0.1825
# Epoch 85/100
# 24/24 [==============================] - 5s 228ms/step - loss: 0.9986 - accuracy: 0.4892 - jacard_coef: 0.2000 - val_loss: 1.0073 - val_accuracy: 0.4586 - val_jacard_coef: 0.1774
# Epoch 86/100
# 24/24 [==============================] - 5s 210ms/step - loss: 0.9988 - accuracy: 0.4931 - jacard_coef: 0.1980 - val_loss: 1.0063 - val_accuracy: 0.4753 - val_jacard_coef: 0.1798
# Epoch 87/100
# 24/24 [==============================] - 5s 210ms/step - loss: 0.9990 - accuracy: 0.4858 - jacard_coef: 0.1987 - val_loss: 1.0080 - val_accuracy: 0.4645 - val_jacard_coef: 0.1782
# Epoch 88/100
# 24/24 [==============================] - 5s 219ms/step - loss: 0.9994 - accuracy: 0.4946 - jacard_coef: 0.1954 - val_loss: 1.0105 - val_accuracy: 0.4719 - val_jacard_coef: 0.1786
# Epoch 89/100
# 24/24 [==============================] - 5s 209ms/step - loss: 0.9992 - accuracy: 0.4892 - jacard_coef: 0.2007 - val_loss: 1.0112 - val_accuracy: 0.4414 - val_jacard_coef: 0.1662
# Epoch 90/100
# 24/24 [==============================] - 5s 212ms/step - loss: 0.9992 - accuracy: 0.4887 - jacard_coef: 0.1960 - val_loss: 1.0092 - val_accuracy: 0.4595 - val_jacard_coef: 0.1665
# Epoch 91/100
# 24/24 [==============================] - 5s 212ms/step - loss: 0.9993 - accuracy: 0.4915 - jacard_coef: 0.1965 - val_loss: 1.0084 - val_accuracy: 0.4585 - val_jacard_coef: 0.1722
# Epoch 92/100
# 24/24 [==============================] - 5s 209ms/step - loss: 0.9978 - accuracy: 0.4958 - jacard_coef: 0.1997 - val_loss: 1.0095 - val_accuracy: 0.4640 - val_jacard_coef: 0.1759
# Epoch 93/100
# 24/24 [==============================] - 5s 213ms/step - loss: 0.9980 - accuracy: 0.4919 - jacard_coef: 0.1999 - val_loss: 1.0112 - val_accuracy: 0.4752 - val_jacard_coef: 0.1774
# Epoch 94/100
# 24/24 [==============================] - 5s 208ms/step - loss: 0.9979 - accuracy: 0.4918 - jacard_coef: 0.2002 - val_loss: 1.0128 - val_accuracy: 0.4704 - val_jacard_coef: 0.1794
# Epoch 95/100
# 24/24 [==============================] - 5s 213ms/step - loss: 0.9991 - accuracy: 0.4880 - jacard_coef: 0.1986 - val_loss: 1.0156 - val_accuracy: 0.4522 - val_jacard_coef: 0.1728
# Epoch 96/100
# 24/24 [==============================] - 5s 209ms/step - loss: 0.9975 - accuracy: 0.4906 - jacard_coef: 0.2002 - val_loss: 1.0185 - val_accuracy: 0.4506 - val_jacard_coef: 0.1768
# Epoch 97/100
# 24/24 [==============================] - 5s 211ms/step - loss: 0.9966 - accuracy: 0.4903 - jacard_coef: 0.2056 - val_loss: 1.0085 - val_accuracy: 0.4440 - val_jacard_coef: 0.1775
# Epoch 98/100
# 24/24 [==============================] - 5s 215ms/step - loss: 0.9957 - accuracy: 0.4915 - jacard_coef: 0.2083 - val_loss: 1.0102 - val_accuracy: 0.4438 - val_jacard_coef: 0.1775
# Epoch 99/100
# 24/24 [==============================] - 5s 210ms/step - loss: 0.9956 - accuracy: 0.4950 - jacard_coef: 0.2085 - val_loss: 1.0077 - val_accuracy: 0.4451 - val_jacard_coef: 0.1785
# Epoch 100/100
# 24/24 [==============================] - 5s 214ms/step - loss: 0.9960 - accuracy: 0.4949 - jacard_coef: 0.2073 - val_loss: 1.0081 - val_accuracy: 0.4384 - val_jacard_coef: 0.1727
# 3/3 [==============================] - 8s 2s/step
# Mean IoU = 0.15578528
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 21ms/step
# Area for each class: {0: 26568, 1: 10923, 3: 23542, 4: 4503}
